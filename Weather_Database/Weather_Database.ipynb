# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 729

# %%
# Import the API key.
from config import weather_api_key

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8f95288aff6efbb2bc949446d3faefe9

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 15 | airai
# Processing Record 2 of Set 15 | arraial do cabo
# Processing Record 3 of Set 15 | busselton
# Processing Record 4 of Set 15 | husavik
# Processing Record 5 of Set 15 | hithadhoo
# Processing Record 6 of Set 15 | fairlie
# Processing Record 7 of Set 15 | parga
# Processing Record 8 of Set 15 | saint-philippe
# Processing Record 9 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 15 | castro
# Processing Record 11 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 15 | butaritari
# Processing Record 13 of Set 15 | hobart
# Processing Record 14 of Set 15 | atuona
# Processing Record 15 of Set 15 | angoche
# Processing Record 16 of Set 15 | tiksi
# Processing Record 17 of Set 15 | port macquarie
# Processing Record 18 of Set 15 | vaini
# Processing Record 19 of Set 15 | sitka
# Processing Record 20 of Set 15 | cap-aux-meules
# Processing Record 21 of Set 15 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 15 | qaanaaq
# Processing Record 23 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 15 | sonoita
# Processing Record 25 of Set 15 | kavieng
# Processing Record 26 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 15 | carnarvon
# Processing Record 28 of Set 15 | georgetown
# Processing Record 29 of Set 15 | severo-kurilsk
# Processing Record 30 of Set 15 | collie
# Processing Record 31 of Set 15 | arcachon
# Processing Record 32 of Set 15 | svetlogorsk
# Processing Record 33 of Set 15 | luanda
# Processing Record 34 of Set 15 | guerrero negro
# Processing Record 35 of Set 15 | geraldton
# Processing Record 36 of Set 15 | mataura
# Processing Record 37 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 38 of Set 15 | syracuse
# Processing Record 39 of Set 15 | ushuaia
# Processing Record 40 of Set 15 | kolda
# Processing Record 41 of Set 15 | fairbanks
# Processing Record 42 of Set 15 | tuktoyaktuk
# Processing Record 43 of Set 15 | leningradskiy
# Processing Record 44 of Set 15 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 15 | vanimo
# Processing Record 46 of Set 15 | ponta delgada
# Processing Record 47 of Set 15 | jamestown
# Processing Record 48 of Set 15 | jati
# Processing Record 49 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 15 | lar
# Processing Record 1 of Set 16 | russell
# Processing Record 2 of Set 16 | chuy
# Processing Record 3 of Set 16 | mananjary
# Processing Record 4 of Set 16 | cape town
# Processing Record 5 of Set 16 | kapaa
# Processing Record 6 of Set 16 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 16 | alofi
# Processing Record 8 of Set 16 | umm durman
# City not found. Skipping...
# Processing Record 9 of Set 16 | paamiut
# Processing Record 10 of Set 16 | caravelas
# Processing Record 11 of Set 16 | cidreira
# Processing Record 12 of Set 16 | slave lake
# Processing Record 13 of Set 16 | lagoa
# Processing Record 14 of Set 16 | wlodawa
# Processing Record 15 of Set 16 | rikitea
# Processing Record 16 of Set 16 | port hardy
# Processing Record 17 of Set 16 | dikson
# Processing Record 18 of Set 16 | jiddah
# City not found. Skipping...
# Processing Record 19 of Set 16 | shelburne
# Processing Record 20 of Set 16 | margate
# Processing Record 21 of Set 16 | port elizabeth
# Processing Record 22 of Set 16 | ambodifototra
# City not found. Skipping...
# Processing Record 23 of Set 16 | bengkulu
# Processing Record 24 of Set 16 | new norfolk
# Processing Record 25 of Set 16 | haibowan
# City not found. Skipping...
# Processing Record 26 of Set 16 | nikolskoye
# Processing Record 27 of Set 16 | saint george
# Processing Record 28 of Set 16 | khatanga
# Processing Record 29 of Set 16 | chihu
# City not found. Skipping...
# Processing Record 30 of Set 16 | kaitangata
# Processing Record 31 of Set 16 | trebukhiv
# Processing Record 32 of Set 16 | lorengau
# Processing Record 33 of Set 16 | wairoa
# Processing Record 34 of Set 16 | xinqing
# Processing Record 35 of Set 16 | tuatapere
# Processing Record 36 of Set 16 | san cosme y damian
# Processing Record 37 of Set 16 | albany
# Processing Record 38 of Set 16 | punta arenas
# Processing Record 39 of Set 16 | vila velha
# Processing Record 40 of Set 16 | chokurdakh
# Processing Record 41 of Set 16 | ambon
# Processing Record 42 of Set 16 | chitral
# Processing Record 43 of Set 16 | port lincoln
# Processing Record 44 of Set 16 | surt
# Processing Record 45 of Set 16 | port alfred
# Processing Record 46 of Set 16 | sosnovo-ozerskoye
# Processing Record 47 of Set 16 | mosquera
# Processing Record 48 of Set 16 | dunedin
# Processing Record 49 of Set 16 | gatton
# Processing Record 50 of Set 16 | inverell
# Processing Record 1 of Set 17 | veraval
# Processing Record 2 of Set 17 | puerto ayora
# Processing Record 3 of Set 17 | tapaua
# City not found. Skipping...
# Processing Record 4 of Set 17 | talnakh
# Processing Record 5 of Set 17 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 17 | belmonte
# Processing Record 7 of Set 17 | qasigiannguit
# Processing Record 8 of Set 17 | longyearbyen
# Processing Record 9 of Set 17 | trincomalee
# Processing Record 10 of Set 17 | naron
# Processing Record 11 of Set 17 | beloha
# Processing Record 12 of Set 17 | avarua
# Processing Record 13 of Set 17 | dolbeau
# City not found. Skipping...
# Processing Record 14 of Set 17 | san felipe
# Processing Record 15 of Set 17 | bonnyville
# Processing Record 16 of Set 17 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 17 | iqaluit
# Processing Record 18 of Set 17 | viligili
# City not found. Skipping...
# Processing Record 19 of Set 17 | narsaq
# Processing Record 20 of Set 17 | san andres
# Processing Record 21 of Set 17 | ilulissat
# Processing Record 22 of Set 17 | wuwei
# Processing Record 23 of Set 17 | tongzi
# Processing Record 24 of Set 17 | flinders
# Processing Record 25 of Set 17 | celestun
# Processing Record 26 of Set 17 | suoyarvi
# Processing Record 27 of Set 17 | mar del plata
# Processing Record 28 of Set 17 | abu samrah
# Processing Record 29 of Set 17 | tazovskiy
# Processing Record 30 of Set 17 | basti
# Processing Record 31 of Set 17 | nanortalik
# Processing Record 32 of Set 17 | burnie
# Processing Record 33 of Set 17 | skage
# City not found. Skipping...
# Processing Record 34 of Set 17 | porto san giorgio
# Processing Record 35 of Set 17 | bambous virieux
# Processing Record 36 of Set 17 | upernavik
# Processing Record 37 of Set 17 | boissevain
# Processing Record 38 of Set 17 | ferzikovo
# Processing Record 39 of Set 17 | soyo
# Processing Record 40 of Set 17 | karratha
# Processing Record 41 of Set 17 | katsuura
# Processing Record 42 of Set 17 | tasiilaq
# Processing Record 43 of Set 17 | tooele
# Processing Record 44 of Set 17 | yerbogachen
# Processing Record 45 of Set 17 | san quintin
# Processing Record 46 of Set 17 | namatanai
# Processing Record 47 of Set 17 | mildura
# Processing Record 48 of Set 17 | kieta
# Processing Record 49 of Set 17 | jalu
# Processing Record 50 of Set 17 | ganzhou
# Processing Record 1 of Set 18 | east london
# Processing Record 2 of Set 18 | saint-francois
# Processing Record 3 of Set 18 | lebu
# Processing Record 4 of Set 18 | saint-paul
# Processing Record 5 of Set 18 | barrow
# Processing Record 6 of Set 18 | mankono
# Processing Record 7 of Set 18 | sedelnikovo
# City not found. Skipping...
# Processing Record 8 of Set 18 | vila franca do campo
# Processing Record 9 of Set 18 | sept-iles
# Processing Record 10 of Set 18 | sanghar
# Processing Record 11 of Set 18 | hermanus
# Processing Record 12 of Set 18 | nizwa
# Processing Record 13 of Set 18 | luderitz
# Processing Record 14 of Set 18 | avigliana
# Processing Record 15 of Set 18 | provideniya
# Processing Record 16 of Set 18 | northam
# Processing Record 17 of Set 18 | coari
# Processing Record 18 of Set 18 | rio gallegos
# Processing Record 19 of Set 18 | ushtobe
# Processing Record 20 of Set 18 | nagorsk
# Processing Record 21 of Set 18 | itarema
# Processing Record 22 of Set 18 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 18 | hovd
# Processing Record 24 of Set 18 | sioux lookout
# Processing Record 25 of Set 18 | bluff
# Processing Record 26 of Set 18 | ribeira grande
# Processing Record 27 of Set 18 | torbay
# Processing Record 28 of Set 18 | hiranagar
# Processing Record 29 of Set 18 | aranos
# Processing Record 30 of Set 18 | skjervoy
# Processing Record 31 of Set 18 | aasiaat
# Processing Record 32 of Set 18 | clyde river
# Processing Record 33 of Set 18 | ngunguru
# Processing Record 34 of Set 18 | nemuro
# Processing Record 35 of Set 18 | nome
# Processing Record 36 of Set 18 | kilindoni
# Processing Record 37 of Set 18 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 18 | norman wells
# Processing Record 39 of Set 18 | victoria
# Processing Record 40 of Set 18 | port shepstone
# Processing Record 41 of Set 18 | isangel
# Processing Record 42 of Set 18 | axim
# Processing Record 43 of Set 18 | rio grande
# Processing Record 44 of Set 18 | yellowknife
# Processing Record 45 of Set 18 | cairns
# Processing Record 46 of Set 18 | morbegno
# Processing Record 47 of Set 18 | nouadhibou
# Processing Record 48 of Set 18 | korla
# Processing Record 49 of Set 18 | saskylakh
# Processing Record 50 of Set 18 | port hedland
# Processing Record 1 of Set 19 | manta
# Processing Record 2 of Set 19 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 19 | tiznit
# Processing Record 4 of Set 19 | the valley
# Processing Record 5 of Set 19 | meulaboh
# Processing Record 6 of Set 19 | cabo san lucas
# Processing Record 7 of Set 19 | vostok
# Processing Record 8 of Set 19 | trinidad
# Processing Record 9 of Set 19 | saldanha
# Processing Record 10 of Set 19 | bredasdorp
# Processing Record 11 of Set 19 | cabra
# Processing Record 12 of Set 19 | necochea
# Processing Record 13 of Set 19 | port-cartier
# Processing Record 14 of Set 19 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 19 | nishihara
# Processing Record 16 of Set 19 | matagami
# Processing Record 17 of Set 19 | patnagarh
# Processing Record 18 of Set 19 | zapolyarnyy
# Processing Record 19 of Set 19 | utiroa
# City not found. Skipping...
# Processing Record 20 of Set 19 | hilo
# Processing Record 21 of Set 19 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 19 | ribera
# Processing Record 23 of Set 19 | avera
# Processing Record 24 of Set 19 | hailar
# Processing Record 25 of Set 19 | bonavista
# Processing Record 26 of Set 19 | mitsamiouli
# Processing Record 27 of Set 19 | tapiramuta
# Processing Record 28 of Set 19 | kargasok
# Processing Record 29 of Set 19 | mogocha
# Processing Record 30 of Set 19 | kununurra
# Processing Record 31 of Set 19 | punto fijo
# Processing Record 32 of Set 19 | pisco
# Processing Record 33 of Set 19 | moba
# Processing Record 34 of Set 19 | trairi
# Processing Record 35 of Set 19 | jingdezhen
# Processing Record 36 of Set 19 | coruripe
# Processing Record 37 of Set 19 | ocos
# Processing Record 38 of Set 19 | banyo
# Processing Record 39 of Set 19 | moose factory
# Processing Record 40 of Set 19 | hasaki
# Processing Record 41 of Set 19 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 19 | santa fe
# Processing Record 43 of Set 19 | diapaga
# Processing Record 44 of Set 19 | bandar-e anzali
# Processing Record 45 of Set 19 | paragominas
# Processing Record 46 of Set 19 | huarmey
# Processing Record 47 of Set 19 | zhezkazgan
# Processing Record 48 of Set 19 | chandur
# Processing Record 49 of Set 19 | la ronge
# Processing Record 50 of Set 19 | mahebourg
# Processing Record 1 of Set 20 | quanzhou
# Processing Record 2 of Set 20 | deputatskiy
# Processing Record 3 of Set 20 | basar
# Processing Record 4 of Set 20 | polunochnoye
# Processing Record 5 of Set 20 | te anau
# Processing Record 6 of Set 20 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 20 | jilib
# Processing Record 8 of Set 20 | nara
# Processing Record 9 of Set 20 | alcala
# Processing Record 10 of Set 20 | gevrai
# Processing Record 11 of Set 20 | brae
# Processing Record 12 of Set 20 | alpinopolis
# Processing Record 13 of Set 20 | cockburn town
# Processing Record 14 of Set 20 | buraydah
# Processing Record 15 of Set 20 | souillac
# Processing Record 16 of Set 20 | erbach
# Processing Record 17 of Set 20 | beringovskiy
# Processing Record 18 of Set 20 | puerto palomas
# Processing Record 19 of Set 20 | port said
# Processing Record 20 of Set 20 | victor harbor
# Processing Record 21 of Set 20 | eyl
# Processing Record 22 of Set 20 | zhicheng
# Processing Record 23 of Set 20 | envira
# Processing Record 24 of Set 20 | marawi
# Processing Record 25 of Set 20 | thompson
# Processing Record 26 of Set 20 | coahuayana
# Processing Record 27 of Set 20 | rawson
# Processing Record 28 of Set 20 | oussouye
# Processing Record 29 of Set 20 | ouro preto do oeste
# Processing Record 30 of Set 20 | kudahuvadhoo
# Processing Record 31 of Set 20 | itapetininga
# Processing Record 32 of Set 20 | hay river
# Processing Record 33 of Set 20 | ngama
# Processing Record 34 of Set 20 | santa maria del oro
# Processing Record 35 of Set 20 | samarai
# Processing Record 36 of Set 20 | kampli
# Processing Record 37 of Set 20 | mount isa
# Processing Record 38 of Set 20 | aginskoye
# Processing Record 39 of Set 20 | severnyy
# Processing Record 40 of Set 20 | bailieborough
# Processing Record 41 of Set 20 | sao filipe
# Processing Record 42 of Set 20 | rock sound
# Processing Record 43 of Set 20 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 20 | dossor
# Processing Record 45 of Set 20 | erzin
# Processing Record 46 of Set 20 | elizabeth city
# Processing Record 47 of Set 20 | codrington
# Processing Record 48 of Set 20 | antofagasta
# Processing Record 49 of Set 20 | henties bay
# Processing Record 50 of Set 20 | padang
# Processing Record 1 of Set 21 | havre-saint-pierre
# Processing Record 2 of Set 21 | lagos
# Processing Record 3 of Set 21 | aykhal
# Processing Record 4 of Set 21 | thilogne
# City not found. Skipping...
# Processing Record 5 of Set 21 | lembang
# Processing Record 6 of Set 21 | xichang
# Processing Record 7 of Set 21 | katha
# City not found. Skipping...
# Processing Record 8 of Set 21 | basco
# Processing Record 9 of Set 21 | aleksandrov gay
# Processing Record 10 of Set 21 | teguise
# Processing Record 11 of Set 21 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 21 | ancud
# Processing Record 13 of Set 21 | taranagar
# Processing Record 14 of Set 21 | nagato
# Processing Record 15 of Set 21 | augustow
# Processing Record 16 of Set 21 | almaznyy
# Processing Record 17 of Set 21 | varhaug
# Processing Record 18 of Set 21 | misratah
# Processing Record 19 of Set 21 | kyzyl-suu
# Processing Record 20 of Set 21 | bethel
# Processing Record 21 of Set 21 | faanui
# Processing Record 22 of Set 21 | hokitika
# Processing Record 23 of Set 21 | sur
# Processing Record 24 of Set 21 | ife
# Processing Record 25 of Set 21 | archidona
# Processing Record 26 of Set 21 | brownsville
# Processing Record 27 of Set 21 | aurangabad
# Processing Record 28 of Set 21 | katangli
# Processing Record 29 of Set 21 | pasighat
# Processing Record 30 of Set 21 | virginia beach
# Processing Record 31 of Set 21 | benguela
# Processing Record 32 of Set 21 | esperance
# Processing Record 33 of Set 21 | namibe
# Processing Record 34 of Set 21 | batemans bay
# Processing Record 35 of Set 21 | goundam
# Processing Record 36 of Set 21 | berlevag
# Processing Record 37 of Set 21 | kavaratti
# Processing Record 38 of Set 21 | iracoubo
# Processing Record 39 of Set 21 | fort nelson
# Processing Record 40 of Set 21 | vieste
# Processing Record 41 of Set 21 | vanderhoof
# Processing Record 42 of Set 21 | san patricio
# Processing Record 43 of Set 21 | ponta do sol
# Processing Record 44 of Set 21 | bandarbeyla
# Processing Record 45 of Set 21 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 21 | oneonta
# Processing Record 47 of Set 21 | saint-joseph
# Processing Record 48 of Set 21 | nanakuli
# Processing Record 49 of Set 21 | hirara
# Processing Record 50 of Set 21 | nampula
# Processing Record 1 of Set 22 | ambilobe
# Processing Record 2 of Set 22 | floro
# Processing Record 3 of Set 22 | oktyabrskoye
# Processing Record 4 of Set 22 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 22 | biaora
# Processing Record 6 of Set 22 | egvekinot
# Processing Record 7 of Set 22 | duz
# City not found. Skipping...
# Processing Record 8 of Set 22 | atar
# Processing Record 9 of Set 22 | ahipara
# Processing Record 10 of Set 22 | keuruu
# Processing Record 11 of Set 22 | salekhard
# Processing Record 12 of Set 22 | galesong
# Processing Record 13 of Set 22 | leira
# Processing Record 14 of Set 22 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 22 | cherskiy
# Processing Record 16 of Set 22 | wanaka
# Processing Record 17 of Set 22 | mandera
# Processing Record 18 of Set 22 | xuddur
# Processing Record 19 of Set 22 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 22 | sorland
# Processing Record 21 of Set 22 | urucara
# Processing Record 22 of Set 22 | pitkyaranta
# Processing Record 23 of Set 22 | dwarka
# Processing Record 24 of Set 22 | marv dasht
# City not found. Skipping...
# Processing Record 25 of Set 22 | mehamn
# Processing Record 26 of Set 22 | kulhudhuffushi
# Processing Record 27 of Set 22 | vardo
# Processing Record 28 of Set 22 | jacmel
# Processing Record 29 of Set 22 | pevek
# Processing Record 30 of Set 22 | bose
# Processing Record 31 of Set 22 | canhaway
# Processing Record 32 of Set 22 | otane
# Processing Record 33 of Set 22 | phan thiet
# Processing Record 34 of Set 22 | tocopilla
# Processing Record 35 of Set 22 | saint-pierre
# Processing Record 36 of Set 22 | kahului
# Processing Record 37 of Set 22 | bafq
# Processing Record 38 of Set 22 | san cristobal
# Processing Record 39 of Set 22 | barcelos
# Processing Record 40 of Set 22 | ixtapa
# Processing Record 41 of Set 22 | srednekolymsk
# Processing Record 42 of Set 22 | mount gambier
# Processing Record 43 of Set 22 | faya
# Processing Record 44 of Set 22 | los llanos de aridane
# Processing Record 45 of Set 22 | ulladulla
# Processing Record 46 of Set 22 | koyelga
# Processing Record 47 of Set 22 | ardabil
# Processing Record 48 of Set 22 | bundibugyo
# Processing Record 49 of Set 22 | kalemie
# Processing Record 50 of Set 22 | lompoc
# Processing Record 1 of Set 23 | charters towers
# Processing Record 2 of Set 23 | vysha
# Processing Record 3 of Set 23 | witrivier
# City not found. Skipping...
# Processing Record 4 of Set 23 | puerto madryn
# Processing Record 5 of Set 23 | salalah
# Processing Record 6 of Set 23 | boshan
# Processing Record 7 of Set 23 | kiruna
# Processing Record 8 of Set 23 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 23 | riyadh
# Processing Record 10 of Set 23 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 23 | mandalgovi
# Processing Record 12 of Set 23 | lanxi
# Processing Record 13 of Set 23 | chipinge
# Processing Record 14 of Set 23 | nuuk
# Processing Record 15 of Set 23 | grand gaube
# Processing Record 16 of Set 23 | maler kotla
# Processing Record 17 of Set 23 | izmaylovo
# Processing Record 18 of Set 23 | carbonia
# Processing Record 19 of Set 23 | talcahuano
# Processing Record 20 of Set 23 | kruisfontein
# Processing Record 21 of Set 23 | port moresby
# Processing Record 22 of Set 23 | muros
# Processing Record 23 of Set 23 | puerto cabezas
# Processing Record 24 of Set 23 | havoysund
# Processing Record 25 of Set 23 | omutinskoye
# City not found. Skipping...
# Processing Record 26 of Set 23 | bonneville
# Processing Record 27 of Set 23 | gursu
# Processing Record 28 of Set 23 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 23 | abiy adi
# City not found. Skipping...
# Processing Record 30 of Set 23 | klaksvik
# Processing Record 31 of Set 23 | wanning
# Processing Record 32 of Set 23 | port keats
# Processing Record 33 of Set 23 | lexington
# Processing Record 34 of Set 23 | camana
# Processing Record 35 of Set 23 | erenhot
# Processing Record 36 of Set 23 | ducheng
# Processing Record 37 of Set 23 | manitouwadge
# Processing Record 38 of Set 23 | maldonado
# Processing Record 39 of Set 23 | hualmay
# Processing Record 40 of Set 23 | paracatu
# Processing Record 41 of Set 23 | challans
# Processing Record 42 of Set 23 | pemba
# Processing Record 43 of Set 23 | sakaiminato
# Processing Record 44 of Set 23 | broome
# Processing Record 45 of Set 23 | constitucion
# Processing Record 46 of Set 23 | dzhusaly
# City not found. Skipping...
# Processing Record 47 of Set 23 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 23 | netivot
# Processing Record 49 of Set 23 | zhigansk
# Processing Record 50 of Set 23 | meadow lake
# Processing Record 1 of Set 24 | acari
# Processing Record 2 of Set 24 | pangnirtung
# Processing Record 3 of Set 24 | port blair
# Processing Record 4 of Set 24 | pressbaum
# Processing Record 5 of Set 24 | urengoy
# Processing Record 6 of Set 24 | concordia
# Processing Record 7 of Set 24 | kodiak
# Processing Record 8 of Set 24 | aklavik
# Processing Record 9 of Set 24 | omboue
# Processing Record 10 of Set 24 | gimli
# Processing Record 11 of Set 24 | thinadhoo
# Processing Record 12 of Set 24 | cukai
# Processing Record 13 of Set 24 | termiz
# Processing Record 14 of Set 24 | vallenar
# Processing Record 15 of Set 24 | labuhan
# Processing Record 16 of Set 24 | camargo
# Processing Record 17 of Set 24 | filadelfia
# Processing Record 18 of Set 24 | miri
# Processing Record 19 of Set 24 | olavarria
# Processing Record 20 of Set 24 | garowe
# Processing Record 21 of Set 24 | valle de allende
# Processing Record 22 of Set 24 | pimentel
# Processing Record 23 of Set 24 | san rafael
# Processing Record 24 of Set 24 | bur gabo
# City not found. Skipping...
# Processing Record 25 of Set 24 | katobu
# Processing Record 26 of Set 24 | morgan city
# Processing Record 27 of Set 24 | roald
# Processing Record 28 of Set 24 | coihaique
# Processing Record 29 of Set 24 | ulaangom
# Processing Record 30 of Set 24 | roebourne
# Processing Record 31 of Set 24 | sandnessjoen
# Processing Record 32 of Set 24 | marshfield
# Processing Record 33 of Set 24 | balkanabat
# Processing Record 34 of Set 24 | bayog
# Processing Record 35 of Set 24 | nicoya
# Processing Record 36 of Set 24 | luwuk
# Processing Record 37 of Set 24 | urusha
# Processing Record 38 of Set 24 | kaduy
# Processing Record 39 of Set 24 | aflu
# City not found. Skipping...
# Processing Record 40 of Set 24 | nantucket
# Processing Record 41 of Set 24 | newtownards
# Processing Record 42 of Set 24 | tricase
# Processing Record 43 of Set 24 | skagastrond
# City not found. Skipping...
# Processing Record 44 of Set 24 | karamay
# City not found. Skipping...
# Processing Record 45 of Set 24 | harstad
# Processing Record 46 of Set 24 | torbat-e jam
# Processing Record 47 of Set 24 | pasco
# Processing Record 48 of Set 24 | pineville
# Processing Record 49 of Set 24 | tambura
# Processing Record 50 of Set 24 | athabasca
# Processing Record 1 of Set 25 | vestmannaeyjar
# Processing Record 2 of Set 25 | cabatuan
# Processing Record 3 of Set 25 | bowen
# Processing Record 4 of Set 25 | rundu
# Processing Record 5 of Set 25 | verkhnevilyuysk
# Processing Record 6 of Set 25 | biu
# Processing Record 7 of Set 25 | lata
# Processing Record 8 of Set 25 | balikpapan
# Processing Record 9 of Set 25 | alihe
# Processing Record 10 of Set 25 | lachi
# Processing Record 11 of Set 25 | karpogory
# Processing Record 12 of Set 25 | prince rupert
# Processing Record 13 of Set 25 | rongcheng
# Processing Record 14 of Set 25 | teutonia
# Processing Record 15 of Set 25 | pretoria
# Processing Record 16 of Set 25 | shelton
# Processing Record 17 of Set 25 | corning
# Processing Record 18 of Set 25 | along
# Processing Record 19 of Set 25 | dokka
# Processing Record 20 of Set 25 | karachi
# Processing Record 21 of Set 25 | sulangan
# Processing Record 22 of Set 25 | yamoussoukro
# Processing Record 23 of Set 25 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 25 | carutapera
# Processing Record 25 of Set 25 | imbituba
# Processing Record 26 of Set 25 | palm coast
# Processing Record 27 of Set 25 | iringa
# Processing Record 28 of Set 25 | zhanaozen
# Processing Record 29 of Set 25 | asau
# Processing Record 30 of Set 25 | makakilo city
# Processing Record 31 of Set 25 | shetpe
# Processing Record 32 of Set 25 | yulara
# Processing Record 33 of Set 25 | valle de guadalupe
# Processing Record 34 of Set 25 | rincon
# Processing Record 35 of Set 25 | kohima
# Processing Record 36 of Set 25 | nizhniye sergi
# Processing Record 37 of Set 25 | camajuani
# Processing Record 38 of Set 25 | aksarka
# Processing Record 39 of Set 25 | mahibadhoo
# Processing Record 40 of Set 25 | camopi
# Processing Record 41 of Set 25 | pesochenskiy
# Processing Record 42 of Set 25 | kazanskoye
# Processing Record 43 of Set 25 | missoula
# Processing Record 44 of Set 25 | santa lucia
# Processing Record 45 of Set 25 | beyneu
# Processing Record 46 of Set 25 | gamba
# Processing Record 47 of Set 25 | ishigaki
# Processing Record 48 of Set 25 | hofn
# Processing Record 49 of Set 25 | waingapu
# Processing Record 50 of Set 25 | yanan
# City not found. Skipping...
# Processing Record 1 of Set 26 | orlik
# Processing Record 2 of Set 26 | kangaatsiaq
# Processing Record 3 of Set 26 | jiuquan
# Processing Record 4 of Set 26 | banda aceh
# Processing Record 5 of Set 26 | narrabri
# Processing Record 6 of Set 26 | gushikawa
# Processing Record 7 of Set 26 | pinawa
# Processing Record 8 of Set 26 | amapa
# Processing Record 9 of Set 26 | esmeraldas
# Processing Record 10 of Set 26 | bitam
# Processing Record 11 of Set 26 | westport
# Processing Record 12 of Set 26 | whitecourt
# Processing Record 13 of Set 26 | high level
# Processing Record 14 of Set 26 | verkh-chebula
# Processing Record 15 of Set 26 | abha
# Processing Record 16 of Set 26 | pueblo bello
# Processing Record 17 of Set 26 | orange
# Processing Record 18 of Set 26 | omsukchan
# Processing Record 19 of Set 26 | mossendjo
# Processing Record 20 of Set 26 | miyako
# Processing Record 21 of Set 26 | sokoni
# Processing Record 22 of Set 26 | neiafu
# Processing Record 23 of Set 26 | kurilsk
# Processing Record 24 of Set 26 | cauquenes
# Processing Record 25 of Set 26 | campbellton
# Processing Record 26 of Set 26 | abu zabad
# Processing Record 27 of Set 26 | olafsvik
# Processing Record 28 of Set 26 | raudeberg
# Processing Record 29 of Set 26 | atherton
# Processing Record 30 of Set 26 | bilibino
# Processing Record 31 of Set 26 | cravo norte
# Processing Record 32 of Set 26 | gold coast
# Processing Record 33 of Set 26 | san isidro
# Processing Record 34 of Set 26 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 26 | usinsk
# Processing Record 36 of Set 26 | tarakan
# Processing Record 37 of Set 26 | san miguel
# Processing Record 38 of Set 26 | mapimi
# Processing Record 39 of Set 26 | sfantu gheorghe
# Processing Record 40 of Set 26 | los alamos
# Processing Record 41 of Set 26 | koupela
# Processing Record 42 of Set 26 | shimoda
# Processing Record 43 of Set 26 | cangucu
# Processing Record 44 of Set 26 | boa vista
# Processing Record 45 of Set 26 | saiha
# Processing Record 46 of Set 26 | ewa beach
# Processing Record 47 of Set 26 | zhangjiakou
# Processing Record 48 of Set 26 | carberry
# Processing Record 49 of Set 26 | mpika
# Processing Record 50 of Set 26 | porto walter
# Processing Record 1 of Set 27 | maralal
# Processing Record 2 of Set 27 | dingle
# Processing Record 3 of Set 27 | antananarivo
# Processing Record 4 of Set 27 | muriti
# Processing Record 5 of Set 27 | alyangula
# Processing Record 6 of Set 27 | bathsheba
# Processing Record 7 of Set 27 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 27 | tabou
# Processing Record 9 of Set 27 | champerico
# Processing Record 10 of Set 27 | bela
# Processing Record 11 of Set 27 | tautira
# Processing Record 12 of Set 27 | olinda
# Processing Record 13 of Set 27 | coquimbo
# Processing Record 14 of Set 27 | mayo
# Processing Record 15 of Set 27 | charleston
# Processing Record 16 of Set 27 | eureka
# Processing Record 17 of Set 27 | komsomolskiy
# Processing Record 18 of Set 27 | ayagoz
# Processing Record 19 of Set 27 | pedernales
# Processing Record 20 of Set 27 | buaran
# Processing Record 21 of Set 27 | guanica
# Processing Record 22 of Set 27 | casablanca
# Processing Record 23 of Set 27 | saquarema
# Processing Record 24 of Set 27 | peterhead
# Processing Record 25 of Set 27 | bilma
# Processing Record 26 of Set 27 | fairmont
# Processing Record 27 of Set 27 | floriano
# Processing Record 28 of Set 27 | flin flon
# Processing Record 29 of Set 27 | aksu
# Processing Record 30 of Set 27 | kertosono
# Processing Record 31 of Set 27 | clarence town
# Processing Record 32 of Set 27 | bubaque
# Processing Record 33 of Set 27 | salto
# Processing Record 34 of Set 27 | sri aman
# Processing Record 35 of Set 27 | taraz
# Processing Record 36 of Set 27 | seoul
# Processing Record 37 of Set 27 | pangody
# Processing Record 38 of Set 27 | acapulco
# Processing Record 39 of Set 27 | grindavik
# Processing Record 40 of Set 27 | limoges
# Processing Record 41 of Set 27 | dunda
# Processing Record 42 of Set 27 | menongue
# Processing Record 43 of Set 27 | gopichettipalaiyam
# City not found. Skipping...
# Processing Record 44 of Set 27 | sonkovo
# Processing Record 45 of Set 27 | vagur
# Processing Record 46 of Set 27 | kutum
# Processing Record 47 of Set 27 | evensk
# Processing Record 48 of Set 27 | hun
# Processing Record 49 of Set 27 | kyshtovka
# Processing Record 50 of Set 27 | chiclana
# Processing Record 1 of Set 28 | zhaocheng
# City not found. Skipping...
# Processing Record 2 of Set 28 | uzunovo
# Processing Record 3 of Set 28 | pali
# Processing Record 4 of Set 28 | hambantota
# Processing Record 5 of Set 28 | klamath falls
# Processing Record 6 of Set 28 | stykkisholmur
# Processing Record 7 of Set 28 | yenagoa
# Processing Record 8 of Set 28 | jacareacanga
# Processing Record 9 of Set 28 | mikhaylovskoye
# Processing Record 10 of Set 28 | assai
# Processing Record 11 of Set 28 | boysun
# Processing Record 12 of Set 28 | tanout
# Processing Record 13 of Set 28 | kikwit
# Processing Record 14 of Set 28 | coimbra
# Processing Record 15 of Set 28 | solnechnyy
# Processing Record 16 of Set 28 | ust-nera
# Processing Record 17 of Set 28 | marly
# Processing Record 18 of Set 28 | shestakovo
# Processing Record 19 of Set 28 | sao francisco
# Processing Record 20 of Set 28 | linxi
# Processing Record 21 of Set 28 | dok kham tai
# Processing Record 22 of Set 28 | igdir
# Processing Record 23 of Set 28 | sechura
# Processing Record 24 of Set 28 | lavrentiya
# Processing Record 25 of Set 28 | wahiawa
# Processing Record 26 of Set 28 | bad laasphe
# Processing Record 27 of Set 28 | sao joao da barra
# Processing Record 28 of Set 28 | minggang
# Processing Record 29 of Set 28 | barvinkove
# Processing Record 30 of Set 28 | male
# Processing Record 31 of Set 28 | bulaevo
# Processing Record 32 of Set 28 | sanquhar
# Processing Record 33 of Set 28 | yar-sale
# Processing Record 34 of Set 28 | mahon
# Processing Record 35 of Set 28 | penjamillo
# City not found. Skipping...
# Processing Record 36 of Set 28 | yelizovo
# Processing Record 37 of Set 28 | awbari
# Processing Record 38 of Set 28 | ocu
# Processing Record 39 of Set 28 | kedrovyy
# Processing Record 40 of Set 28 | jiwani
# Processing Record 41 of Set 28 | kentau
# Processing Record 42 of Set 28 | adrar
# Processing Record 43 of Set 28 | gunjur
# Processing Record 44 of Set 28 | ouadda
# Processing Record 45 of Set 28 | cap malheureux
# Processing Record 46 of Set 28 | camacupa
# Processing Record 47 of Set 28 | jeremie
# Processing Record 48 of Set 28 | hervey bay
# Processing Record 49 of Set 28 | auki
# Processing Record 50 of Set 28 | sangmelima
# Processing Record 1 of Set 29 | kollumerland
# City not found. Skipping...
# Processing Record 2 of Set 29 | matara
# Processing Record 3 of Set 29 | houma
# Processing Record 4 of Set 29 | aquiraz
# Processing Record 5 of Set 29 | kapit
# Processing Record 6 of Set 29 | tanete
# Processing Record 7 of Set 29 | elat
# Processing Record 8 of Set 29 | aldan
# Processing Record 9 of Set 29 | artyk
# City not found. Skipping...
# Processing Record 10 of Set 29 | robe
# Processing Record 11 of Set 29 | ruwi
# Processing Record 12 of Set 29 | portland
# Processing Record 13 of Set 29 | xacmaz
# Processing Record 14 of Set 29 | ossora
# Processing Record 15 of Set 29 | lemesos
# City not found. Skipping...
# Processing Record 16 of Set 29 | jatibonico
# Processing Record 17 of Set 29 | boende
# Processing Record 18 of Set 29 | yushu
# Processing Record 19 of Set 29 | anadyr
# Processing Record 20 of Set 29 | ca mau
# Processing Record 21 of Set 29 | mujiayingzi
# Processing Record 22 of Set 29 | pampas
# Processing Record 23 of Set 29 | phuket
# Processing Record 24 of Set 29 | prince albert
# Processing Record 25 of Set 29 | acarau
# Processing Record 26 of Set 29 | norton
# Processing Record 27 of Set 29 | inuvik
# Processing Record 28 of Set 29 | carmen
# Processing Record 29 of Set 29 | sokolow podlaski
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Airai  -8.9266  125.4092     60.28        95         100
# 1  Arraial Do Cabo -22.9661  -42.0278     89.60        74          20
# 2        Busselton -33.6500  115.3333     55.00        94           0
# 3          Husavik  66.0449  -17.3389     33.80        47          20
# 4        Hithadhoo  -0.6000   73.0833     80.29        84         100
# 5          Fairlie  55.7560   -4.8556     53.60        94          90
# 6            Parga  39.2831   20.3964     59.00        77          20
# 7   Saint-Philippe -21.3585   55.7679     78.80        78           0
# 8           Castro -24.7911  -50.0119     73.31        80         100
# 9       Butaritari   3.0707  172.7902     80.92        76          47
#
#    Wind Speed Country   Current Description
# 0        2.21      TL       overcast clouds
# 1        9.22      BR            few clouds
# 2        6.29      AU             clear sky
# 3        8.05      IS            few clouds
# 4       27.89      MV  heavy intensity rain
# 5       32.21      GB  heavy intensity rain
# 6        4.61      GR            few clouds
# 7        6.91      RE             clear sky
# 8        5.95      BR       overcast clouds
# 9       11.45      KI            light rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df =city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Airai      TL  -8.9266  125.4092     60.28        95         100
# 1  Arraial Do Cabo      BR -22.9661  -42.0278     89.60        74          20
# 2        Busselton      AU -33.6500  115.3333     55.00        94           0
# 3          Husavik      IS  66.0449  -17.3389     33.80        47          20
# 4        Hithadhoo      MV  -0.6000   73.0833     80.29        84         100
# 5          Fairlie      GB  55.7560   -4.8556     53.60        94          90
# 6            Parga      GR  39.2831   20.3964     59.00        77          20
# 7   Saint-Philippe      RE -21.3585   55.7679     78.80        78           0
# 8           Castro      BR -24.7911  -50.0119     73.31        80         100
# 9       Butaritari      KI   3.0707  172.7902     80.92        76          47
#
#    Wind Speed   Current Description
# 0        2.21       overcast clouds
# 1        9.22            few clouds
# 2        6.29             clear sky
# 3        8.05            few clouds
# 4       27.89  heavy intensity rain
# 5       32.21  heavy intensity rain
# 6        4.61            few clouds
# 7        6.91             clear sky
# 8        5.95       overcast clouds
# 9       11.45            light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-85c3a7d8006d> in <module>
#       2 output_data_file = "Weather_Database/WeatherPy_Database.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     188                 encoding=self.encoding,
#     189                 errors=self.errors,
# --> 190                 compression=dict(self.compression_args, method=self.compression),
#     191             )
#     192             close = True
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
