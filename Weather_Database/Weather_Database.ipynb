# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Import the API key.
from config import weather_api_key

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8f95288aff6efbb2bc949446d3faefe9

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 15 | sorong
# Processing Record 2 of Set 15 | kaitangata
# Processing Record 3 of Set 15 | cape town
# Processing Record 4 of Set 15 | huarmey
# Processing Record 5 of Set 15 | victoria
# Processing Record 6 of Set 15 | hilo
# Processing Record 7 of Set 15 | east london
# Processing Record 8 of Set 15 | nago
# Processing Record 9 of Set 15 | rikitea
# Processing Record 10 of Set 15 | codrington
# Processing Record 11 of Set 15 | lanzhou
# Processing Record 12 of Set 15 | asau
# Processing Record 13 of Set 15 | lompoc
# Processing Record 14 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 15 | puerto ayora
# Processing Record 16 of Set 15 | vanimo
# Processing Record 17 of Set 15 | busselton
# Processing Record 18 of Set 15 | bayir
# Processing Record 19 of Set 15 | bandarbeyla
# Processing Record 20 of Set 15 | albany
# Processing Record 21 of Set 15 | tarauaca
# Processing Record 22 of Set 15 | upernavik
# Processing Record 23 of Set 15 | yellowknife
# Processing Record 24 of Set 15 | ishigaki
# Processing Record 25 of Set 15 | ponta do sol
# Processing Record 26 of Set 15 | mataura
# Processing Record 27 of Set 15 | mitsamiouli
# Processing Record 28 of Set 15 | new norfolk
# Processing Record 29 of Set 15 | nhulunbuy
# Processing Record 30 of Set 15 | maceio
# Processing Record 31 of Set 15 | atuona
# Processing Record 32 of Set 15 | provideniya
# Processing Record 33 of Set 15 | thompson
# Processing Record 34 of Set 15 | bredasdorp
# Processing Record 35 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 36 of Set 15 | bluff
# Processing Record 37 of Set 15 | zapolyarnyy
# Processing Record 38 of Set 15 | swan hill
# Processing Record 39 of Set 15 | bilma
# Processing Record 40 of Set 15 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 15 | balkhash
# Processing Record 42 of Set 15 | roebourne
# Processing Record 43 of Set 15 | ushuaia
# Processing Record 44 of Set 15 | sinegorskiy
# Processing Record 45 of Set 15 | narsaq
# Processing Record 46 of Set 15 | mahebourg
# Processing Record 47 of Set 15 | barrow
# Processing Record 48 of Set 15 | jamestown
# Processing Record 49 of Set 15 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 15 | nuuk
# Processing Record 1 of Set 16 | faanui
# Processing Record 2 of Set 16 | geraldton
# Processing Record 3 of Set 16 | luderitz
# Processing Record 4 of Set 16 | sabha
# Processing Record 5 of Set 16 | butaritari
# Processing Record 6 of Set 16 | lebu
# Processing Record 7 of Set 16 | toora-khem
# Processing Record 8 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 16 | dawlatabad
# Processing Record 10 of Set 16 | libertador general san martin
# Processing Record 11 of Set 16 | san juan
# Processing Record 12 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 16 | aksaray
# Processing Record 14 of Set 16 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 16 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 16 | bambous virieux
# Processing Record 17 of Set 16 | rio brilhante
# Processing Record 18 of Set 16 | kapaa
# Processing Record 19 of Set 16 | cockburn town
# Processing Record 20 of Set 16 | rakhya
# City not found. Skipping...
# Processing Record 21 of Set 16 | punta arenas
# Processing Record 22 of Set 16 | cumaribo
# City not found. Skipping...
# Processing Record 23 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 16 | vaini
# Processing Record 25 of Set 16 | pisco
# Processing Record 26 of Set 16 | salalah
# Processing Record 27 of Set 16 | hithadhoo
# Processing Record 28 of Set 16 | bengkulu
# Processing Record 29 of Set 16 | saint george
# Processing Record 30 of Set 16 | hurghada
# Processing Record 31 of Set 16 | payo
# Processing Record 32 of Set 16 | noboribetsu
# Processing Record 33 of Set 16 | ancud
# Processing Record 34 of Set 16 | la fleche
# Processing Record 35 of Set 16 | kruisfontein
# Processing Record 36 of Set 16 | qaqortoq
# Processing Record 37 of Set 16 | hobart
# Processing Record 38 of Set 16 | khatanga
# Processing Record 39 of Set 16 | hermanus
# Processing Record 40 of Set 16 | hasaki
# Processing Record 41 of Set 16 | yaan
# Processing Record 42 of Set 16 | katsuura
# Processing Record 43 of Set 16 | arbazh
# Processing Record 44 of Set 16 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 16 | dingle
# Processing Record 46 of Set 16 | saint-philippe
# Processing Record 47 of Set 16 | tuktoyaktuk
# Processing Record 48 of Set 16 | airai
# Processing Record 49 of Set 16 | nemuro
# Processing Record 50 of Set 16 | avarua
# Processing Record 1 of Set 17 | videira
# Processing Record 2 of Set 17 | lucapa
# Processing Record 3 of Set 17 | vila velha
# Processing Record 4 of Set 17 | klaksvik
# Processing Record 5 of Set 17 | chokurdakh
# Processing Record 6 of Set 17 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 17 | burgeo
# Processing Record 8 of Set 17 | camopi
# Processing Record 9 of Set 17 | saskylakh
# Processing Record 10 of Set 17 | mar del plata
# Processing Record 11 of Set 17 | leningradskiy
# Processing Record 12 of Set 17 | severo-kurilsk
# Processing Record 13 of Set 17 | georgetown
# Processing Record 14 of Set 17 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 17 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 17 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 17 | fortuna
# Processing Record 18 of Set 17 | esperance
# Processing Record 19 of Set 17 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 17 | tambopata
# Processing Record 21 of Set 17 | clyde river
# Processing Record 22 of Set 17 | kamenskiy
# Processing Record 23 of Set 17 | tual
# Processing Record 24 of Set 17 | komsomolskiy
# Processing Record 25 of Set 17 | sherpur
# Processing Record 26 of Set 17 | cherskiy
# Processing Record 27 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 17 | nyanguge
# Processing Record 29 of Set 17 | kupang
# Processing Record 30 of Set 17 | dunedin
# Processing Record 31 of Set 17 | cabo san lucas
# Processing Record 32 of Set 17 | hami
# Processing Record 33 of Set 17 | samarai
# Processing Record 34 of Set 17 | alofi
# Processing Record 35 of Set 17 | camas
# Processing Record 36 of Set 17 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 17 | paamiut
# Processing Record 39 of Set 17 | aksu
# Processing Record 40 of Set 17 | zhangjiakou
# Processing Record 41 of Set 17 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 17 | kumano
# Processing Record 43 of Set 17 | bethel
# Processing Record 44 of Set 17 | inhambane
# Processing Record 45 of Set 17 | namibe
# Processing Record 46 of Set 17 | tura
# Processing Record 47 of Set 17 | boguchany
# Processing Record 48 of Set 17 | flinders
# Processing Record 49 of Set 17 | bundaberg
# Processing Record 50 of Set 17 | praxedis guerrero
# Processing Record 1 of Set 18 | tasiilaq
# Processing Record 2 of Set 18 | hambantota
# Processing Record 3 of Set 18 | nikolskoye
# Processing Record 4 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 18 | tashla
# Processing Record 6 of Set 18 | vila
# Processing Record 7 of Set 18 | arraial do cabo
# Processing Record 8 of Set 18 | longyearbyen
# Processing Record 9 of Set 18 | floro
# Processing Record 10 of Set 18 | lodja
# Processing Record 11 of Set 18 | tari
# Processing Record 12 of Set 18 | necochea
# Processing Record 13 of Set 18 | karratha
# Processing Record 14 of Set 18 | sharlyk
# Processing Record 15 of Set 18 | carnarvon
# Processing Record 16 of Set 18 | virginia beach
# Processing Record 17 of Set 18 | belaya gora
# Processing Record 18 of Set 18 | avera
# Processing Record 19 of Set 18 | el tigre
# Processing Record 20 of Set 18 | pokaran
# Processing Record 21 of Set 18 | preeceville
# Processing Record 22 of Set 18 | saldanha
# Processing Record 23 of Set 18 | comodoro rivadavia
# Processing Record 24 of Set 18 | qaanaaq
# Processing Record 25 of Set 18 | kaohsiung
# Processing Record 26 of Set 18 | bar harbor
# Processing Record 27 of Set 18 | iqaluit
# Processing Record 28 of Set 18 | korla
# Processing Record 29 of Set 18 | srednekolymsk
# Processing Record 30 of Set 18 | castro
# Processing Record 31 of Set 18 | mingyue
# Processing Record 32 of Set 18 | grindavik
# Processing Record 33 of Set 18 | quatre cocos
# Processing Record 34 of Set 18 | matara
# Processing Record 35 of Set 18 | baruun-urt
# Processing Record 36 of Set 18 | mali
# Processing Record 37 of Set 18 | pochutla
# Processing Record 38 of Set 18 | port hedland
# Processing Record 39 of Set 18 | lewistown
# Processing Record 40 of Set 18 | oda
# Processing Record 41 of Set 18 | gladstone
# Processing Record 42 of Set 18 | sao sebastiao
# Processing Record 43 of Set 18 | tessalit
# Processing Record 44 of Set 18 | xiangfan
# Processing Record 45 of Set 18 | matamoros
# Processing Record 46 of Set 18 | shimoda
# Processing Record 47 of Set 18 | vardo
# Processing Record 48 of Set 18 | vestmannaeyjar
# Processing Record 49 of Set 18 | ilulissat
# Processing Record 50 of Set 18 | san quintin
# Processing Record 1 of Set 19 | seoul
# Processing Record 2 of Set 19 | yulara
# Processing Record 3 of Set 19 | ribeira grande
# Processing Record 4 of Set 19 | aklavik
# Processing Record 5 of Set 19 | port alfred
# Processing Record 6 of Set 19 | lata
# Processing Record 7 of Set 19 | quelimane
# Processing Record 8 of Set 19 | shingu
# Processing Record 9 of Set 19 | rio gallegos
# Processing Record 10 of Set 19 | aripuana
# Processing Record 11 of Set 19 | bend
# Processing Record 12 of Set 19 | ksenyevka
# City not found. Skipping...
# Processing Record 13 of Set 19 | jimeta
# Processing Record 14 of Set 19 | cap malheureux
# Processing Record 15 of Set 19 | pampas
# Processing Record 16 of Set 19 | guerrero
# Processing Record 17 of Set 19 | ambon
# Processing Record 18 of Set 19 | russell
# Processing Record 19 of Set 19 | kiunga
# Processing Record 20 of Set 19 | okoneshnikovo
# Processing Record 21 of Set 19 | port lincoln
# Processing Record 22 of Set 19 | yerbogachen
# Processing Record 23 of Set 19 | port blair
# Processing Record 24 of Set 19 | tiksi
# Processing Record 25 of Set 19 | saint-pierre
# Processing Record 26 of Set 19 | tuatapere
# Processing Record 27 of Set 19 | inta
# Processing Record 28 of Set 19 | panzhihua
# Processing Record 29 of Set 19 | markova
# Processing Record 30 of Set 19 | pacific grove
# Processing Record 31 of Set 19 | saint-augustin
# Processing Record 32 of Set 19 | kudahuvadhoo
# Processing Record 33 of Set 19 | dikson
# Processing Record 34 of Set 19 | cayenne
# Processing Record 35 of Set 19 | ketchikan
# Processing Record 36 of Set 19 | honningsvag
# Processing Record 37 of Set 19 | hualmay
# Processing Record 38 of Set 19 | castelldefels
# Processing Record 39 of Set 19 | dunda
# Processing Record 40 of Set 19 | mazagao
# Processing Record 41 of Set 19 | chuy
# Processing Record 42 of Set 19 | orocue
# Processing Record 43 of Set 19 | marrakesh
# Processing Record 44 of Set 19 | arlit
# Processing Record 45 of Set 19 | husavik
# Processing Record 46 of Set 19 | jinchang
# Processing Record 47 of Set 19 | tanout
# Processing Record 48 of Set 19 | ostrovnoy
# Processing Record 49 of Set 19 | adrar
# Processing Record 50 of Set 19 | marzuq
# Processing Record 1 of Set 20 | morro bay
# Processing Record 2 of Set 20 | wuan
# Processing Record 3 of Set 20 | awbari
# Processing Record 4 of Set 20 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 20 | mazatlan
# Processing Record 6 of Set 20 | chernyshevskiy
# Processing Record 7 of Set 20 | meadow lake
# Processing Record 8 of Set 20 | sola
# Processing Record 9 of Set 20 | okha
# Processing Record 10 of Set 20 | prince rupert
# Processing Record 11 of Set 20 | kavieng
# Processing Record 12 of Set 20 | gorin
# Processing Record 13 of Set 20 | sur
# Processing Record 14 of Set 20 | susehri
# Processing Record 15 of Set 20 | lorengau
# Processing Record 16 of Set 20 | port-gentil
# Processing Record 17 of Set 20 | havre-saint-pierre
# Processing Record 18 of Set 20 | chingirlau
# Processing Record 19 of Set 20 | thunder bay
# Processing Record 20 of Set 20 | pevek
# Processing Record 21 of Set 20 | kholm
# Processing Record 22 of Set 20 | merauke
# Processing Record 23 of Set 20 | vostok
# Processing Record 24 of Set 20 | connersville
# Processing Record 25 of Set 20 | misawa
# Processing Record 26 of Set 20 | zhangzhou
# Processing Record 27 of Set 20 | teya
# Processing Record 28 of Set 20 | jabiru
# City not found. Skipping...
# Processing Record 29 of Set 20 | hovd
# Processing Record 30 of Set 20 | pemberton
# Processing Record 31 of Set 20 | mandalgovi
# Processing Record 32 of Set 20 | biak
# Processing Record 33 of Set 20 | urumqi
# Processing Record 34 of Set 20 | san vicente
# Processing Record 35 of Set 20 | bull savanna
# Processing Record 36 of Set 20 | acarau
# Processing Record 37 of Set 20 | barra do bugres
# Processing Record 38 of Set 20 | sitka
# Processing Record 39 of Set 20 | udachnyy
# Processing Record 40 of Set 20 | souillac
# Processing Record 41 of Set 20 | buala
# Processing Record 42 of Set 20 | hervey bay
# Processing Record 43 of Set 20 | khovu-aksy
# Processing Record 44 of Set 20 | the valley
# Processing Record 45 of Set 20 | hobyo
# Processing Record 46 of Set 20 | vila franca do campo
# Processing Record 47 of Set 20 | ahipara
# Processing Record 48 of Set 20 | acapulco
# Processing Record 49 of Set 20 | el alto
# Processing Record 50 of Set 20 | kahului
# Processing Record 1 of Set 21 | sisimiut
# Processing Record 2 of Set 21 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 21 | nome
# Processing Record 4 of Set 21 | nadym
# Processing Record 5 of Set 21 | puerto baquerizo moreno
# Processing Record 6 of Set 21 | ampanihy
# Processing Record 7 of Set 21 | ranong
# Processing Record 8 of Set 21 | alamosa
# Processing Record 9 of Set 21 | novyy urengoy
# Processing Record 10 of Set 21 | hollister
# Processing Record 11 of Set 21 | sistranda
# Processing Record 12 of Set 21 | baza
# Processing Record 13 of Set 21 | timmins
# Processing Record 14 of Set 21 | hofn
# Processing Record 15 of Set 21 | oistins
# Processing Record 16 of Set 21 | trinidad
# Processing Record 17 of Set 21 | ossora
# Processing Record 18 of Set 21 | constitucion
# Processing Record 19 of Set 21 | berlevag
# Processing Record 20 of Set 21 | zaozerne
# Processing Record 21 of Set 21 | ploemeur
# Processing Record 22 of Set 21 | dicabisagan
# Processing Record 23 of Set 21 | norman wells
# Processing Record 24 of Set 21 | marystown
# Processing Record 25 of Set 21 | nishihara
# Processing Record 26 of Set 21 | fagernes
# Processing Record 27 of Set 21 | byron bay
# Processing Record 28 of Set 21 | mabaruma
# Processing Record 29 of Set 21 | sarangani
# Processing Record 30 of Set 21 | goderich
# Processing Record 31 of Set 21 | najran
# Processing Record 32 of Set 21 | makokou
# Processing Record 33 of Set 21 | bozoum
# Processing Record 34 of Set 21 | chapais
# Processing Record 35 of Set 21 | port elizabeth
# Processing Record 36 of Set 21 | batagay
# Processing Record 37 of Set 21 | tsabong
# Processing Record 38 of Set 21 | pangnirtung
# Processing Record 39 of Set 21 | nouadhibou
# Processing Record 40 of Set 21 | bolshaya glushitsa
# Processing Record 41 of Set 21 | bodden town
# Processing Record 42 of Set 21 | fairbanks
# Processing Record 43 of Set 21 | ust-kuyga
# Processing Record 44 of Set 21 | koumac
# Processing Record 45 of Set 21 | alihe
# Processing Record 46 of Set 21 | honiara
# Processing Record 47 of Set 21 | miyako
# Processing Record 48 of Set 21 | rocha
# Processing Record 49 of Set 21 | pangai
# Processing Record 50 of Set 21 | isangel
# Processing Record 1 of Set 22 | san cristobal
# Processing Record 2 of Set 22 | obo
# Processing Record 3 of Set 22 | akrini
# Processing Record 4 of Set 22 | krasnogorsk
# Processing Record 5 of Set 22 | kampot
# Processing Record 6 of Set 22 | greenfield
# Processing Record 7 of Set 22 | trairi
# Processing Record 8 of Set 22 | gayny
# Processing Record 9 of Set 22 | corum
# Processing Record 10 of Set 22 | buritis
# Processing Record 11 of Set 22 | ichhawar
# Processing Record 12 of Set 22 | bato
# Processing Record 13 of Set 22 | greencastle
# Processing Record 14 of Set 22 | zeerust
# Processing Record 15 of Set 22 | stokmarknes
# Processing Record 16 of Set 22 | filadelfia
# Processing Record 17 of Set 22 | dzerzhinsk
# Processing Record 18 of Set 22 | pachino
# Processing Record 19 of Set 22 | kodiak
# Processing Record 20 of Set 22 | kirakira
# Processing Record 21 of Set 22 | barreiras
# Processing Record 22 of Set 22 | mecca
# Processing Record 23 of Set 22 | kitimat
# Processing Record 24 of Set 22 | broome
# Processing Record 25 of Set 22 | guerrero negro
# Processing Record 26 of Set 22 | praya
# Processing Record 27 of Set 22 | cracow
# Processing Record 28 of Set 22 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 22 | sabla
# Processing Record 30 of Set 22 | cidreira
# Processing Record 31 of Set 22 | skjervoy
# Processing Record 32 of Set 22 | chicama
# Processing Record 33 of Set 22 | kavaratti
# Processing Record 34 of Set 22 | khuzhir
# Processing Record 35 of Set 22 | seymchan
# Processing Record 36 of Set 22 | gulshat
# City not found. Skipping...
# Processing Record 37 of Set 22 | henties bay
# Processing Record 38 of Set 22 | banagher
# Processing Record 39 of Set 22 | menzelinsk
# Processing Record 40 of Set 22 | bongaree
# Processing Record 41 of Set 22 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 22 | soyo
# Processing Record 43 of Set 22 | mangai
# Processing Record 44 of Set 22 | mocambique
# City not found. Skipping...
# Processing Record 45 of Set 22 | keningau
# Processing Record 46 of Set 22 | kontagora
# Processing Record 47 of Set 22 | cacule
# Processing Record 48 of Set 22 | uwayl
# City not found. Skipping...
# Processing Record 49 of Set 22 | ballina
# Processing Record 50 of Set 22 | naryan-mar
# Processing Record 1 of Set 23 | beira
# Processing Record 2 of Set 23 | chongoyape
# Processing Record 3 of Set 23 | lumberton
# Processing Record 4 of Set 23 | arman
# Processing Record 5 of Set 23 | urdoma
# Processing Record 6 of Set 23 | mancio lima
# Processing Record 7 of Set 23 | maine-soroa
# Processing Record 8 of Set 23 | bunbury
# Processing Record 9 of Set 23 | harnosand
# Processing Record 10 of Set 23 | tautira
# Processing Record 11 of Set 23 | tigil
# Processing Record 12 of Set 23 | port augusta
# Processing Record 13 of Set 23 | nyurba
# Processing Record 14 of Set 23 | gamba
# Processing Record 15 of Set 23 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 23 | touros
# Processing Record 17 of Set 23 | walvis bay
# Processing Record 18 of Set 23 | mackay
# Processing Record 19 of Set 23 | sumbe
# Processing Record 20 of Set 23 | lagoa
# Processing Record 21 of Set 23 | kaeo
# Processing Record 22 of Set 23 | homer
# Processing Record 23 of Set 23 | dossor
# Processing Record 24 of Set 23 | talnakh
# Processing Record 25 of Set 23 | santo antonio do sudoeste
# Processing Record 26 of Set 23 | rovaniemi
# Processing Record 27 of Set 23 | bairiki
# Processing Record 28 of Set 23 | coxim
# Processing Record 29 of Set 23 | matata
# Processing Record 30 of Set 23 | doha
# Processing Record 31 of Set 23 | tsaratanana
# Processing Record 32 of Set 23 | yar-sale
# Processing Record 33 of Set 23 | camana
# Processing Record 34 of Set 23 | calvinia
# Processing Record 35 of Set 23 | kalianget
# Processing Record 36 of Set 23 | itoman
# Processing Record 37 of Set 23 | loukhi
# Processing Record 38 of Set 23 | ixtapa
# Processing Record 39 of Set 23 | san felipe
# Processing Record 40 of Set 23 | new smyrna beach
# Processing Record 41 of Set 23 | kununurra
# Processing Record 42 of Set 23 | te anau
# Processing Record 43 of Set 23 | tefe
# Processing Record 44 of Set 23 | pundaguitan
# Processing Record 45 of Set 23 | vargashi
# Processing Record 46 of Set 23 | tanete
# Processing Record 47 of Set 23 | cartagena del chaira
# Processing Record 48 of Set 23 | nantucket
# Processing Record 49 of Set 23 | wellington
# Processing Record 50 of Set 23 | sao jose da coroa grande
# Processing Record 1 of Set 24 | lazi
# Processing Record 2 of Set 24 | opuwo
# Processing Record 3 of Set 24 | ust-uda
# Processing Record 4 of Set 24 | northam
# Processing Record 5 of Set 24 | kamenka
# Processing Record 6 of Set 24 | springbok
# Processing Record 7 of Set 24 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 24 | kargasok
# Processing Record 9 of Set 24 | nuevo imperial
# Processing Record 10 of Set 24 | port keats
# Processing Record 11 of Set 24 | foso
# Processing Record 12 of Set 24 | kaspiysk
# Processing Record 13 of Set 24 | zhigansk
# Processing Record 14 of Set 24 | san pedro
# Processing Record 15 of Set 24 | grand gaube
# Processing Record 16 of Set 24 | ukiah
# Processing Record 17 of Set 24 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 24 | shubarshi
# Processing Record 19 of Set 24 | zolotkovo
# Processing Record 20 of Set 24 | biltine
# Processing Record 21 of Set 24 | manacapuru
# Processing Record 22 of Set 24 | vao
# Processing Record 23 of Set 24 | salar
# Processing Record 24 of Set 24 | benemerito de las americas
# Processing Record 25 of Set 24 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 24 | farrukhnagar
# Processing Record 27 of Set 24 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 24 | sabang
# Processing Record 29 of Set 24 | fairfield
# Processing Record 30 of Set 24 | meridian
# Processing Record 31 of Set 24 | hamilton
# Processing Record 32 of Set 24 | nokha
# Processing Record 33 of Set 24 | dalby
# Processing Record 34 of Set 24 | manzil tamim
# City not found. Skipping...
# Processing Record 35 of Set 24 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 36 of Set 24 | lasa
# Processing Record 37 of Set 24 | yerofey pavlovich
# Processing Record 38 of Set 24 | bathsheba
# Processing Record 39 of Set 24 | sabzevar
# Processing Record 40 of Set 24 | saiha
# Processing Record 41 of Set 24 | elk grove
# Processing Record 42 of Set 24 | kamennomostskoye
# Processing Record 43 of Set 24 | atar
# Processing Record 44 of Set 24 | deputatskiy
# Processing Record 45 of Set 24 | rognan
# Processing Record 46 of Set 24 | abu dhabi
# Processing Record 47 of Set 24 | tommot
# Processing Record 48 of Set 24 | poum
# Processing Record 49 of Set 24 | winneba
# Processing Record 50 of Set 24 | richards bay
# Processing Record 1 of Set 25 | mezen
# Processing Record 2 of Set 25 | mapiri
# Processing Record 3 of Set 25 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 25 | college
# Processing Record 5 of Set 25 | mount pleasant
# Processing Record 6 of Set 25 | tikrit
# Processing Record 7 of Set 25 | torbay
# Processing Record 8 of Set 25 | pathein
# Processing Record 9 of Set 25 | samana
# Processing Record 10 of Set 25 | mayumba
# Processing Record 11 of Set 25 | great yarmouth
# Processing Record 12 of Set 25 | darnetal
# Processing Record 13 of Set 25 | krasnoselkup
# Processing Record 14 of Set 25 | bardiyah
# Processing Record 15 of Set 25 | bilibino
# Processing Record 16 of Set 25 | charters towers
# Processing Record 17 of Set 25 | olutanga
# Processing Record 18 of Set 25 | tadine
# Processing Record 19 of Set 25 | mogadishu
# Processing Record 20 of Set 25 | praia
# Processing Record 21 of Set 25 | flin flon
# Processing Record 22 of Set 25 | beba
# Processing Record 23 of Set 25 | batemans bay
# Processing Record 24 of Set 25 | darnah
# Processing Record 25 of Set 25 | waipawa
# Processing Record 26 of Set 25 | beloha
# Processing Record 27 of Set 25 | porto santo
# Processing Record 28 of Set 25 | pringsewu
# Processing Record 29 of Set 25 | abakaliki
# Processing Record 30 of Set 25 | sao filipe
# Processing Record 31 of Set 25 | san ramon
# Processing Record 32 of Set 25 | antsohihy
# Processing Record 33 of Set 25 | gotsu
# Processing Record 34 of Set 25 | havoysund
# Processing Record 35 of Set 25 | ouegoa
# Processing Record 36 of Set 25 | giaveno
# Processing Record 37 of Set 25 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 25 | kerteh
# City not found. Skipping...
# Processing Record 39 of Set 25 | ola
# Processing Record 40 of Set 25 | albina
# Processing Record 41 of Set 25 | ulaangom
# Processing Record 42 of Set 25 | guanhaes
# Processing Record 43 of Set 25 | areia branca
# Processing Record 44 of Set 25 | hirara
# Processing Record 45 of Set 25 | petauke
# Processing Record 46 of Set 25 | panaba
# Processing Record 47 of Set 25 | jumilla
# Processing Record 48 of Set 25 | elko
# Processing Record 49 of Set 25 | sechura
# Processing Record 50 of Set 25 | ulladulla
# Processing Record 1 of Set 26 | lavrentiya
# Processing Record 2 of Set 26 | rumoi
# Processing Record 3 of Set 26 | inuvik
# Processing Record 4 of Set 26 | kingsland
# Processing Record 5 of Set 26 | roald
# Processing Record 6 of Set 26 | sharanga
# Processing Record 7 of Set 26 | shahrud
# Processing Record 8 of Set 26 | conceicao do araguaia
# Processing Record 9 of Set 26 | armacao dos buzios
# City not found. Skipping...
# Processing Record 10 of Set 26 | gombong
# Processing Record 11 of Set 26 | bjornevatn
# Processing Record 12 of Set 26 | cascais
# Processing Record 13 of Set 26 | astoria
# Processing Record 14 of Set 26 | raudeberg
# Processing Record 15 of Set 26 | porto novo
# Processing Record 16 of Set 26 | banska bystrica
# Processing Record 17 of Set 26 | barawe
# City not found. Skipping...
# Processing Record 18 of Set 26 | santo antonio do leverger
# Processing Record 19 of Set 26 | manaure
# Processing Record 20 of Set 26 | serenje
# Processing Record 21 of Set 26 | langsa
# Processing Record 22 of Set 26 | saint-felix-de-valois
# Processing Record 23 of Set 26 | vengerovo
# Processing Record 24 of Set 26 | machilipatnam
# Processing Record 25 of Set 26 | westport
# Processing Record 26 of Set 26 | chute-aux-outardes
# Processing Record 27 of Set 26 | antofagasta
# Processing Record 28 of Set 26 | isabela
# Processing Record 29 of Set 26 | borba
# Processing Record 30 of Set 26 | peniche
# Processing Record 31 of Set 26 | wang saphung
# Processing Record 32 of Set 26 | nathdwara
# Processing Record 33 of Set 26 | ambilobe
# Processing Record 34 of Set 26 | severo-yeniseyskiy
# Processing Record 35 of Set 26 | solnechnyy
# Processing Record 36 of Set 26 | bela vista
# Processing Record 37 of Set 26 | lincoln
# Processing Record 38 of Set 26 | arica
# Processing Record 39 of Set 26 | wadi musa
# Processing Record 40 of Set 26 | kloulklubed
# Processing Record 41 of Set 26 | graham
# Processing Record 42 of Set 26 | mahadday weyne
# City not found. Skipping...
# Processing Record 43 of Set 26 | daru
# Processing Record 44 of Set 26 | ipixuna
# Processing Record 45 of Set 26 | cuamba
# Processing Record 46 of Set 26 | rabaul
# Processing Record 47 of Set 26 | grand baie
# Processing Record 48 of Set 26 | saint anthony
# Processing Record 49 of Set 26 | nusaybin
# Processing Record 50 of Set 26 | puerto el triunfo
# Processing Record 1 of Set 27 | haines junction
# Processing Record 2 of Set 27 | palmer
# Processing Record 3 of Set 27 | ilmenau
# Processing Record 4 of Set 27 | sogne
# Processing Record 5 of Set 27 | santa cruz cabralia
# Processing Record 6 of Set 27 | scarborough
# Processing Record 7 of Set 27 | mormugao
# Processing Record 8 of Set 27 | murgab
# Processing Record 9 of Set 27 | eyrarbakki
# Processing Record 10 of Set 27 | san fernando
# Processing Record 11 of Set 27 | lisakovsk
# Processing Record 12 of Set 27 | puerto escondido
# Processing Record 13 of Set 27 | diego de almagro
# Processing Record 14 of Set 27 | shuiji
# Processing Record 15 of Set 27 | watsa
# Processing Record 16 of Set 27 | phitsanulok
# Processing Record 17 of Set 27 | yumen
# Processing Record 18 of Set 27 | bakchar
# Processing Record 19 of Set 27 | forbes
# Processing Record 20 of Set 27 | ha tinh
# Processing Record 21 of Set 27 | nichinan
# Processing Record 22 of Set 27 | anadyr
# Processing Record 23 of Set 27 | cam ranh
# Processing Record 24 of Set 27 | iskateley
# Processing Record 25 of Set 27 | cervo
# Processing Record 26 of Set 27 | troitskaya
# Processing Record 27 of Set 27 | labutta
# City not found. Skipping...
# Processing Record 28 of Set 27 | rosetta
# Processing Record 29 of Set 27 | birjand
# Processing Record 30 of Set 27 | port hueneme
# Processing Record 31 of Set 27 | sungaipenuh
# Processing Record 32 of Set 27 | namie
# Processing Record 33 of Set 27 | formoso do araguaia
# City not found. Skipping...
# Processing Record 34 of Set 27 | zarand
# Processing Record 35 of Set 27 | powell
# Processing Record 36 of Set 27 | yantal
# Processing Record 37 of Set 27 | balikpapan
# Processing Record 38 of Set 27 | alpena
# Processing Record 39 of Set 27 | hoopstad
# Processing Record 40 of Set 27 | ler
# Processing Record 41 of Set 27 | san isidro
# Processing Record 42 of Set 27 | san jose del guaviare
# Processing Record 43 of Set 27 | amapa
# Processing Record 44 of Set 27 | mehamn
# Processing Record 45 of Set 27 | guaranda
# Processing Record 46 of Set 27 | jalu
# Processing Record 47 of Set 27 | srandakan
# Processing Record 48 of Set 27 | pontianak
# Processing Record 49 of Set 27 | okhotsk
# Processing Record 50 of Set 27 | falciu
# Processing Record 1 of Set 28 | gizo
# Processing Record 2 of Set 28 | gweru
# Processing Record 3 of Set 28 | kuandian
# Processing Record 4 of Set 28 | black river
# Processing Record 5 of Set 28 | axim
# Processing Record 6 of Set 28 | borogontsy
# Processing Record 7 of Set 28 | play cu
# City not found. Skipping...
# Processing Record 8 of Set 28 | sterling
# Processing Record 9 of Set 28 | kobryn
# Processing Record 10 of Set 28 | jiaojiang
# Processing Record 11 of Set 28 | adzope
# Processing Record 12 of Set 28 | zuenoula
# Processing Record 13 of Set 28 | asasa
# Processing Record 14 of Set 28 | ozinki
# Processing Record 15 of Set 28 | jalingo
# Processing Record 16 of Set 28 | olafsvik
# Processing Record 17 of Set 28 | maniitsoq
# Processing Record 18 of Set 28 | berezayka
# Processing Record 19 of Set 28 | newport
# Processing Record 20 of Set 28 | sambava
# Processing Record 21 of Set 28 | podgornoye
# Processing Record 22 of Set 28 | genhe
# Processing Record 23 of Set 28 | kyshtovka
# Processing Record 24 of Set 28 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 28 | mawlaik
# Processing Record 26 of Set 28 | geresk
# City not found. Skipping...
# Processing Record 27 of Set 28 | sobolevo
# Processing Record 28 of Set 28 | tikapur
# Processing Record 29 of Set 28 | nkhotakota
# Processing Record 30 of Set 28 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 28 | vista hermosa
# Processing Record 32 of Set 28 | liuzhou
# Processing Record 33 of Set 28 | karasburg
# Processing Record 34 of Set 28 | kapit
# Processing Record 35 of Set 28 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 28 | tomarovka
# Processing Record 37 of Set 28 | totness
# Processing Record 38 of Set 28 | nehe
# Processing Record 39 of Set 28 | sao joao da barra
# Processing Record 40 of Set 28 | namatanai
# Processing Record 41 of Set 28 | little current
# Processing Record 42 of Set 28 | peleduy
# Processing Record 43 of Set 28 | taltal
# Processing Record 44 of Set 28 | pindiga
# Processing Record 45 of Set 28 | zonguldak
# Processing Record 46 of Set 28 | bowen
# Processing Record 47 of Set 28 | qesarya
# Processing Record 48 of Set 28 | kurtamysh
# Processing Record 49 of Set 28 | dinsor
# City not found. Skipping...
# Processing Record 50 of Set 28 | padang
# Processing Record 1 of Set 29 | joshimath
# Processing Record 2 of Set 29 | tashara
# Processing Record 3 of Set 29 | coquimbo
# Processing Record 4 of Set 29 | hengyang
# Processing Record 5 of Set 29 | yeppoon
# Processing Record 6 of Set 29 | taguatinga
# Processing Record 7 of Set 29 | tromso
# Processing Record 8 of Set 29 | fuyang
# Processing Record 9 of Set 29 | astana
# Processing Record 10 of Set 29 | sunrise manor
# Processing Record 11 of Set 29 | newcastle
# Processing Record 12 of Set 29 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 29 | linxia
# Processing Record 14 of Set 29 | myitkyina
# Processing Record 15 of Set 29 | tocopilla
# Processing Record 16 of Set 29 | terrace
# Processing Record 17 of Set 29 | nanortalik
# Processing Record 18 of Set 29 | chipata
# Processing Record 19 of Set 29 | ginda
# Processing Record 20 of Set 29 | cairns
# Processing Record 21 of Set 29 | nefteyugansk
# Processing Record 22 of Set 29 | tiznit
# Processing Record 23 of Set 29 | lucea
# Processing Record 24 of Set 29 | andenes
# Processing Record 25 of Set 29 | rypefjord
# Processing Record 26 of Set 29 | murakami
# Processing Record 27 of Set 29 | loreto
# Processing Record 28 of Set 29 | igrim
# Processing Record 29 of Set 29 | atambua
# Processing Record 30 of Set 29 | jackson
# Processing Record 31 of Set 29 | lozova
# Processing Record 32 of Set 29 | svetlaya
# Processing Record 33 of Set 29 | bontang
# Processing Record 34 of Set 29 | nylstroom
# City not found. Skipping...
# Processing Record 35 of Set 29 | senmonorom
# City not found. Skipping...
# Processing Record 36 of Set 29 | waling
# Processing Record 37 of Set 29 | bonavista
# Processing Record 38 of Set 29 | tevaitoa
# Processing Record 39 of Set 29 | barra
# Processing Record 40 of Set 29 | turayf
# Processing Record 41 of Set 29 | penzance
# Processing Record 42 of Set 29 | orlik
# Processing Record 43 of Set 29 | dondo
# Processing Record 44 of Set 29 | san andres
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Sorong  -0.8833  131.2500     79.03        84         100        1.03
# 1   Kaitangata -46.2817  169.8464     64.99        76          42        1.99
# 2    Cape Town -33.9258   18.4232     66.99        77           0        1.14
# 3      Huarmey -10.0681  -78.1522     71.02        82          94        8.63
# 4     Victoria  22.2855  114.1577     78.01        87          26        7.09
# 5         Hilo  19.7297 -155.0900     73.40        73          90        9.13
# 6  East London -33.0153   27.9116     65.16        78         100       13.49
# 7         Nago  26.5881  127.9761     73.40        94          75        5.75
# 8      Rikitea -23.1203 -134.9692     79.30        74           2       15.55
# 9   Codrington -38.2667  141.9667     61.90        61          90        5.59
#
#   Country Current Description
# 0      ID     overcast clouds
# 1      NZ    scattered clouds
# 2      ZA           clear sky
# 3      PE     overcast clouds
# 4      HK    scattered clouds
# 5      US       moderate rain
# 6      ZA     overcast clouds
# 7      JP                mist
# 8      PF           clear sky
# 9      AU     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df =city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Sorong      ID  -0.8833  131.2500     79.03        84         100
# 1   Kaitangata      NZ -46.2817  169.8464     64.99        76          42
# 2    Cape Town      ZA -33.9258   18.4232     66.99        77           0
# 3      Huarmey      PE -10.0681  -78.1522     71.02        82          94
# 4     Victoria      HK  22.2855  114.1577     78.01        87          26
# 5         Hilo      US  19.7297 -155.0900     73.40        73          90
# 6  East London      ZA -33.0153   27.9116     65.16        78         100
# 7         Nago      JP  26.5881  127.9761     73.40        94          75
# 8      Rikitea      PF -23.1203 -134.9692     79.30        74           2
# 9   Codrington      AU -38.2667  141.9667     61.90        61          90
#
#    Wind Speed Current Description
# 0        1.03     overcast clouds
# 1        1.99    scattered clouds
# 2        1.14           clear sky
# 3        8.63     overcast clouds
# 4        7.09    scattered clouds
# 5        9.13       moderate rain
# 6       13.49     overcast clouds
# 7        5.75                mist
# 8       15.55           clear sky
# 9        5.59     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = 'WeatherPy_Database.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
